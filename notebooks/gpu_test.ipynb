# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print(
    "GPU:",
    torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Not detected",
)
# Out:
# PyTorch: 2.13.0+cu130
# CUDA available: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import sys

import torch

print("Python:", sys.executable)
print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
print(
    "GPU:",
    torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Not detected",
)
# Out:
# Python: /home/jacquez/projects/ai-test/.venv/bin/python
# PyTorch: 2.13.0+cu130
# CUDA: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
